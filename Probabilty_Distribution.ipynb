# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammedfaizal1310-web/Numpy-Excersises/blob/main/Probabilty_Distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
fig , axes=plt.subplots(2,3,figsize=(14,8))
###Binomial Distribution
from scipy.stats import binom
n,p=20,0.4
x=np.arange(0,n+1)
axes[0,0].bar(x,(binom.pmf(x,n,p)), color='mediumseagreen')
axes[0,0].set_title(f'Binomial (n={n}) (p={p})')

####Normal Distribution
mu , sigma=0,1
x=np.linspace(-4,4,10000)
normal=(1/(sigma*(np.sqrt(2*np.pi)))*np.exp(-(x-mu)**2/(2*sigma**2)))
axes[0,1].plot(x,normal)
axes[0,1].set_title('Normal Distribution')

####Bernoulli Distribution
outcomes=[0,1]
p=0.3
probs=[1-p,p]
axes[0,2].bar(outcomes,probs,color='steelblue')
axes[0,2].set_title(f'Bernoulli Distribution (p={p})')
axes[0,2].set_xticks(outcomes)

####Poisson Distribution
from scipy.stats import poisson
x=np.arange(0,15)
lam=4
axes[1,0].bar(x,lam,color='mediumpurple')
axes[1,0].set_title(f'Poisson Distribution (lam={lam})')

##Uniform Distribution
from scipy.stats import uniform
samples=np.random.uniform(-4,4,10000)
axes[1,1].hist(samples,bins=5,density=True, color='gold', edgecolor='white')
axes[1,1].set_title('Uniform Distribution')


###Exponential Distribution
from scipy.stats import expon
x=np.linspace(0,5,300)
axes[1,2].plot(x,expon.pdf(x,scale=1), color='tomato',linewidth='2')
axes[1,2].fill_between(x,expon.pdf(x,scale=1),color='tomato',alpha=0.5)
axes[1,2].set_title('Exponential Distribution')
plt.suptitle('Probability distributions in ML', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()
